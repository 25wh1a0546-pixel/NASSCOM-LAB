# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0546-pixel/NASSCOM-LAB/blob/main/lists%2Ctuple%2Csets_and_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)

# Accessing elements by index
print("First fruit:", fruits[0])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
fruits.append('orange')
print("after appending:",fruits)
# Out:
# after appending: ['apple', 'banana', 'cherry', 'apple', 'orange']

# %%
fruits.remove('banana')
print("after removing",fruits)
# Out:
# after removing ['apple', 'cherry', 'apple', 'orange']

# %%
dimensions=(10,20,30)
print("tuple:",dimensions)
# Out:
# tuple: (10, 20, 30)

# %%
print("second element",dimensions[1])
# Out:
# second element 20

# %%
set={1,2,3,2,1}
print("set (no duplicates):",set)
# Out:
# set (no duplicates): {1, 2, 3}

# %%
set.add(4)
print("after adding:",set)
# Out:
# after adding: {1, 2, 3, 4}

# %%
set.remove(4)
print("after removing:",set)
# Out:
# after removing: {1, 2, 3}

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
student = {
    'name': 'Alice',
    'age': 21,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Alice', 'age': 21, 'course': 'Python'}

# %%
print("Student name:", student['name'])
# Out:
# Student name: Alice

# %%
student['grade'] = 'A'
print("After adding grade:", student)


del student['age']
print("After deleting age:", student)


for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Alice', 'age': 21, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Alice', 'course': 'Python', 'grade': 'A'}
# name: Alice
# course: Python
# grade: A

# %%
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}
