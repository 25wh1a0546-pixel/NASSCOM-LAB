# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0546-pixel/NASSCOM-LAB/blob/main/working_with_core_pythons_and_libraries_and_os_datatime_and_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os


print("Current Directory:", os.getcwd())

print("Files and Folders:", os.listdir())

os.mkdir("demo_folder")
os.rename("demo_folder", "renamed_folder")
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %%
from datetime import datetime, date, timedelta


now = datetime.now()
print("Now:", now)


today = date.today()
print("Today's Date:", today)


dob = date(2000, 1, 1)
print("DOB:", dob)


yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)

print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)


formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-07-13 05:46:29.346227
# Today's Date: 2026-07-13
# DOB: 2000-01-01
# Yesterday: 2026-07-12
# Tomorrow: 2026-07-14
# Formatted DateTime: 13-07-2026 05:46:29

# %%
import random


print("Random Int:", random.randint(1, 100))

print("Random Float:", random.random())


colors = ['red', 'green', 'blue']
print("Random Color:", random.choice(colors))


random.shuffle(colors)
print("Shuffled List:", colors)

print("Sample:", random.sample(range(1, 50), 5))
# Out:
# Random Int: 73
# Random Float: 0.6729188530995032
# Random Color: green
# Shuffled List: ['green', 'red', 'blue']
# Sample: [18, 45, 42, 6, 39]

# %%
from collections import Counter


fruits = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'apple': 3, 'banana': 2, 'orange': 1})

# %%
from collections import defaultdict


marks = defaultdict(lambda: 0)
marks['Math'] = 90
marks['Science'] = 80
print("English Marks (not set):", marks['English'])
# Out:
# English Marks (not set): 0

# %%
from collections import namedtuple


Point = namedtuple('Point', 'x y')
p1 = Point(10, 20)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=10, y=20)
# x: 10 y: 20

# %%
from collections import deque


dq = deque([1, 2, 3])
dq.append(4)
dq.appendleft(0)
dq.pop()
dq.popleft()
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3])
